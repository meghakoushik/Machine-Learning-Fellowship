# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sb
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression  
import os
import pickle
import sklearn

# %%
data_module= pd.read_csv("test.csv")
data_module
# Out:
#       temp  cnt
# 0     0.56    7
# 1     0.44    5
# 2     0.44  743
# 3     0.26  208
# 4     0.66  333
# 5     0.34  187
# 6     0.30  124
# 7     0.70  925
# 8     0.50  212
# 9     0.34  161
# 10    0.72  253
# 11    0.32  207
# 12    0.44   64
# 13    0.58  268
# 14    0.62  114
# 15    0.46  501
# 16    0.42  480
# 17    0.60  591
# 18    0.62  275
# 19    0.80  284
# 20    0.20    5
# 21    0.72  307
# 22    0.60    4
# 23    0.50    6
# 24    0.62  431
# 25    0.16   33
# 26    0.80  505
# 27    0.60  267
# 28    0.64  243
# 29    0.50  154
# ...    ...  ...
# 5184  0.54  305
# 5185  0.46  145
# 5186  0.42  677
# 5187  0.64  659
# 5188  0.74   26
# 5189  0.32  126
# 5190  0.50  487
# 5191  0.78  164
# 5192  0.62  225
# 5193  0.52  401
# 5194  0.36   97
# 5195  0.26    1
# 5196  0.64  539
# 5197  0.06   34
# 5198  0.44   22
# 5199  0.86  487
# 5200  0.20  110
# 5201  0.64   61
# 5202  0.28   63
# 5203  0.62  191
# 5204  0.74  524
# 5205  0.34  190
# 5206  0.74  404
# 5207  0.26  220
# 5208  0.60  293
# 5209  0.64   35
# 5210  0.78  571
# 5211  0.76  499
# 5212  0.58  302
# 5213  0.52  229
#
# [5214 rows x 2 columns]

# %%
# separate labels and features
x_test=data_module.iloc[:,:-1].values
y_test=data_module.iloc[:,1].values

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (5214, 1)
# (5214,)

# %%
regressor = LinearRegression()  
regressor.fit( x_test, y_test)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
file1= open("train_data.pkl",'rb')
regressor1=pickle.load(file1)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-29-aa759a2caa2f> in <module>
#       1 file1= open("train_data.pkl",'rb')
# ----> 2 regressor1=pickle.load(file1)
#       3 file1.close()
#
# EOFError: Ran out of input

# %%
y_pred=regressor1.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-462d0e48eeab> in <module>
# ----> 1 y_pred=regressor1.predict(x_test)
#
# NameError: name 'regressor1' is not defined

# %%
# # calculating accuracy on y_test data of test dataset
accuracy=sklearn.metrics.r2_score(y_test,y_pred)*100
print("Accuracy of test data =",accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-30c39969f4ab> in <module>
#       1 # # calculating accuracy on y_test data of test dataset
# ----> 2 accuracy=sklearn.metrics.r2_score(y_test,y_pred)*100
#       3 print("Accuracy of test data =",accuracy)
#
# NameError: name 'y_pred' is not defined

# %%
# #visualizing the train result
# plt.scatter(x_test,y_test,color='red')
# plt.plot(x_test,regressor.predict(x_test),color='blue')
# plt.title("truth or bluff")
# plt.xlabel("possition")
# plt.ylabel("Salary")
# plt.show()
